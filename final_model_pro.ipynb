# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Read data
df=pd.read_excel('final_data.xlsx')
df
# Out:
#      SR. NO            Item name Supplier  Total Opening Stock in kgs  \
# 0       NaN                  NaN      NaN                         NaN
# 1       NaN                  NaN      NaN                         NaN
# 2       1.0    MAGNI PAINT B06JA    Magni                 1316.940660
# 3       2.0    MAGNI PAINT B06JA    Magni                 1061.236890
# 4       3.0    MAGNI PAINT B06JA    Magni                  618.420798
# ..      ...                  ...      ...                         ...
# 117   116.0  MAGNI PAINT BT - 48    Magni                  242.076330
# 118   117.0  MAGNI PAINT BT - 48    Magni                  257.975010
# 119   118.0  MAGNI PAINT BT - 48    Magni                  241.924914
# 120   119.0  MAGNI PAINT BT - 48    Magni                  232.385706
# 121   120.0  MAGNI PAINT BT - 48    Magni                  210.203262
#
#      Total Production. Kg (P1+P2)  Paint consume. Kg  Clsoing stock      Month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   SR. NO                        120 non-null    float64
#  1   Item name                     120 non-null    object
#  2   Supplier                      120 non-null    object
#  3   Total Opening Stock in kgs    120 non-null    float64
#  4   Total Production. Kg (P1+P2)  120 non-null    float64
#  5   Paint consume. Kg             120 non-null    float64
#  6   Clsoing stock                 120 non-null    float64
#  7   Month                         120 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(2)
# memory usage: 7.8+ KB

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
df.drop(['SR. NO','Supplier','Month'],axis=1,inplace=True)

# %%
df
# Out:
#                Item name  Total Opening Stock in kgs  \
# 0                    NaN                         NaN
# 1                    NaN                         NaN
# 2      MAGNI PAINT B06JA                 1316.940660
# 3      MAGNI PAINT B06JA                 1061.236890
# 4      MAGNI PAINT B06JA                  618.420798
# ..                   ...                         ...
# 117  MAGNI PAINT BT - 48                  242.076330
# 118  MAGNI PAINT BT - 48                  257.975010
# 119  MAGNI PAINT BT - 48                  241.924914
# 120  MAGNI PAINT BT - 48                  232.385706
# 121  MAGNI PAINT BT - 48                  210.203262
#
#      Total Production. Kg (P1+P2)  Paint consume. Kg  Clsoing stock
# 0                             NaN                NaN            NaN
# 1                             NaN                NaN            NaN
# 2                       139283.25           684.8750     632.065660
# ...

# %%
lbl=LabelEncoder()
df['Item name']=lbl.fit_transform(df['Item name'])
df['Item name']
# Out:
# 0      10
# 1      10
# 2       3
# 3       3
# 4       3
#        ..
# 117     4
# 118     4
# 119     4
# 120     4
# 121     4
# Name: Item name, Length: 122, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Item name                     122 non-null    int32
#  1   Total Opening Stock in kgs    120 non-null    float64
#  2   Total Production. Kg (P1+P2)  120 non-null    float64
#  3   Paint consume. Kg             120 non-null    float64
#  4   Clsoing stock                 120 non-null    float64
# dtypes: float64(4), int32(1)
# memory usage: 4.4 KB

# %%
sns.boxplot(x= df['Total Opening Stock in kgs'])
# Out:
# <AxesSubplot:xlabel='Total Opening Stock in kgs'>

# %%
sns.boxplot(x= df['Total Production. Kg (P1+P2)'])
# Out:
# <AxesSubplot:xlabel='Total Production. Kg (P1+P2)'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Item name                     122 non-null    int32
#  1   Total Opening Stock in kgs    120 non-null    float64
#  2   Total Production. Kg (P1+P2)  120 non-null    float64
#  3   Paint consume. Kg             120 non-null    float64
#  4   Clsoing stock                 120 non-null    float64
# dtypes: float64(4), int32(1)
# memory usage: 4.4 KB

# %%
df['Total Opening Stock in kgs'].isna().sum()
# Out:
# 2

# %%
df['Total Opening Stock in kgs']=df['Total Opening Stock in kgs'].fillna(df['Total Opening Stock in kgs'].median)

# %%
df['Total Opening Stock in kgs'].isna().sum()
# Out:
# 0

# %%
df['Total Opening Stock in kgs']=df['Total Opening Stock in kgs'].astype=int

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Item name                     122 non-null    int32
#  1   Total Opening Stock in kgs    122 non-null    object
#  2   Total Production. Kg (P1+P2)  120 non-null    float64
#  3   Paint consume. Kg             120 non-null    float64
#  4   Clsoing stock                 120 non-null    float64
# dtypes: float64(3), int32(1), object(1)
# memory usage: 4.4+ KB

# %%
x = df.drop('Clsoing stock',axis=1)
y = df['Clsoing stock']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
#scaling
normal_scaler = MinMaxScaler()
normal_arr = normal_scaler.fit_transform(x)
normal_df_x = pd.DataFrame(normal_arr,columns= x.columns)
normal_df_x
# Out:
#      Item name  Total Opening Stock in kgs  Total Production. Kg (P1+P2)  \
# 0          1.0                         NaN                           NaN
# 1          1.0                         NaN                           NaN
# 2          0.3                    0.516814                      0.690106
# 3          0.3                    0.412758                      0.745448
# 4          0.3                    0.232558                      0.725639
# ..         ...                         ...                           ...
# 117        0.4                    0.079409                      0.019819
# 118        0.4                    0.085879                      0.000000
# 119        0.4                    0.079347                      0.057901
# 120        0.4                    0.075466                      0.047075
# 121        0.4                    0.066439                      0.000000
#
#      Paint consume. Kg
# 0                  NaN
# 1                  NaN
# ...

# %%
sns.boxplot(df['Total Opening Stock in kgs'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total Opening Stock in kgs'>

# %%
df['Total Opening Stock in kgs']=np.log(df['Total Opening Stock in kgs'])

# %%
sns.boxplot(df['Total Opening Stock in kgs'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total Opening Stock in kgs'>

# %%
sns.boxplot(df['Total Production. Kg (P1+P2)'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total Production. Kg (P1+P2)'>

# %%
df['Total Production. Kg (P1+P2)']=np.log(df['Total Production. Kg (P1+P2)'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.boxplot(df['Total Production. Kg (P1+P2)'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total Production. Kg (P1+P2)'>

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12140/690721473.py in <module>
#       1 model=LinearRegression()
# ----> 2 model.fit(x_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     682         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     683
# --> 684         X, y = self._validate_data(
#     685             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     686         )
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     594                 y = check_array(y, input_name="y", **check_y_params)
#     595             else:
# --> 596                 X, y = check_X_y(X, y, **check_params)
#     597             out = X, y
#     598
#
# ...
